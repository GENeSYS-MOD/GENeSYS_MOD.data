# %%
import os
import pandas as pd
import openpyxl

# Define the directory where your CSV files are located
csv_directory = 'csvs'  # Change this to the directory containing your CSV files

# Define the file to exclude
excluded_file = 'Sets.csv'

# Define the directory where you want to save the filtered CSV files
output_csv_directory = 'output_csv'  # Change this to the directory where you want to save the filtered CSV files

# Create the output directory for CSV files if it doesn't exist
os.makedirs(output_csv_directory, exist_ok=True)

# Define the directory where you want to save the Excel file
output_excel_directory = 'output_excel'  # Change this to the directory where you want to save the Excel file

# Create the output directory for the Excel file if it doesn't exist
os.makedirs(output_excel_directory, exist_ok=True)

# Specify the Excel file path
excel_file_path = 'GENeSYS-MOD_User_Input_Settings_v03_phe_06-09-2023.xlsx'

# %%
# Create a list of sheet names to read
sheets_to_read = ['Region_selection', 'Technology_selection', 'Storage_selection', 'Fuel_selection', 'Mode_of_operation_selection', 'Emission_selection', 'Modal_type_selection', 'Sector_selection', 'Year_selection']

# Initialize an empty dictionary to store DataFrames
data_frames = {}
filtered_df = {}
unique_values = {}

unique_values_concatenated = pd.DataFrame()
column_list = []

# Read sheets and store them in the dictionary
for sheet_name in sheets_to_read:
    data_frames = pd.read_excel(excel_file_path, engine='openpyxl', sheet_name=sheet_name)

    filtered_df= data_frames[data_frames.iloc[:, 1] == 1]# Assuming the second column is indexed at 1 (0-based index)

    column_list.append(filtered_df.columns[0]) # collect column header for each set sheet
    
    unique_values= pd.DataFrame(filtered_df.iloc[:, 0].unique())  # Assuming the first column is indexed at 0 (0-based index)
    unique_values_parameter = pd.DataFrame(unique_values)
    
    unique_values_concatenated = pd.concat([unique_values_concatenated, unique_values], axis=1)
    
# Need to put header to the dataframe
unique_values_concatenated.columns = column_list
  
# Create a CSV file containing unique values
unique_values_csv_file_path = os.path.join(output_csv_directory, 'Sets.csv')
unique_values_concatenated.to_csv(unique_values_csv_file_path, index=False, decimal=',')

# %%
# Initialize an empty dictionary to store DataFrames
data_frames = {}

# %%
# Initialize the Excel writer
output_excel_file_path = os.path.join(output_excel_directory, 'output.xlsx')
with pd.ExcelWriter(output_excel_file_path, engine='openpyxl') as writer:
    
    unique_values_concatenated.to_excel(writer, sheet_name='Sets', index=False, header=True)

    for filename in os.listdir(csv_directory):
        print(filename)
        if filename.endswith('.csv') and filename != excluded_file:
            # Construct the full path to the CSV file
            csv_file_path = os.path.join(csv_directory, filename)
            
            # Read the CSV file into a Pandas DataFrame, skipping the first 4 rows
            df = pd.read_csv(csv_file_path, delimiter=';', skiprows=4)
            
            # Create an empty dictionary to store filtered DataFrames
            filtered_df = df
            
            # Iterate over unique_values_concatenated DataFrame columns
            for header in unique_values_concatenated.columns:
                print(header)
                if header in df.columns:
                    # Filter the DataFrame based on whether the values in the header column are present in unique_values_concatenated
                    #print(unique_values_concatenated[header])
                    
                    condition = filtered_df[header].isin(unique_values_concatenated[header])
                    #filtered_df = filtered_df[filtered_df[header].isin(unique_values_concatenated[header])]
                    if [condition] == True:
                        filtered_df = filtered_df[condition]
                    else:
                        filtered_df = filtered_df[condition]
                        print('Something in the user input does not have data in the data sheets')
                
            filtered_df = pd.concat([filtered_df.columns.to_frame().T, filtered_df], ignore_index=True)
            filtered_df.columns = range(len(df.columns))
            
            # Get the worksheet name without the .csv extension
            worksheet_name = os.path.splitext(filename)[0]
            
            # Store the DataFrame in the dictionary with the filename (without extension) as the key
            data_frames[worksheet_name] = filtered_df
            
            # Write the DataFrame to an Excel worksheet with the same filename (without extension)
            filtered_df.to_excel(writer, sheet_name=worksheet_name, index=False, header=False)
            
            # Construct the full path to the output CSV file
            output_csv_file_path = os.path.join(output_csv_directory, filename)
            
            # Save the filtered DataFrame to the CSV file without the index
            filtered_df.to_csv(output_csv_file_path, index=False, header=False, decimal=',')
# Out:
# Par_OutputActivityRatio.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Something in the user input does not have data in the data sheets
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_FixedCost.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TradeCosts.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_ReserveMarginTagFuel.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_OperationalLife.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_ResidualCapacity.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_RegionalBaseYearProduction.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_MinStorageCharge.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Something in the user input does not have data in the data sheets
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_ModelPeriodActivityMaxLimit.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# .DS_Store
# Par_StorageMaxDischargeRate.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_RegionalAnnualEmissionLimit.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_DaySplit.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_Conversionlh.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_VariableCost.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Something in the user input does not have data in the data sheets
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_AnnualSectoralEmissionLimit.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_AvailabilityFactor.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_SpecifiedAnnualDemand.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_AnnualEmissionLimit.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_TotalAnnualMaxActivity.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_BaseYearProduction.csv
# Region
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_ReserveMargin.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_GrowthRateTradeCapacity.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TechnologyToStorage.csv
# Region
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TagTechnologyToModalType.csv
# Region
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Something in the user input does not have data in the data sheets
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_StorageMaxChargeRate.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TradeCapacity.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TotalAnnualMinCapacity.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_YearSplit.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_ReserveMarginTagTechnology.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TechnologyFromStorage.csv
# Region
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_CapacityFactor.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_AnnualExogenousEmission.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_OperationalLifeStorage.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_EmissionPenaltyTagTech.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_ResidualStorageCapacity.csv
# Region
# Technology
# Storage
# Something in the user input does not have data in the data sheets
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_InputActivityRatio.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Something in the user input does not have data in the data sheets
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_EmissionsPenalty.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_ModalSplitByFuel.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_CapitalCostStorage.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Something in the user input does not have data in the data sheets
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_EmissionActivityRatio.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_Conversionls.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_Conversionld.csv
# Region
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TradeCapacityGrowthCosts.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TotalAnnualMinActivity.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Sets.csv
# Par_EmissionContentPerFuel.csv
# Region
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Something in the user input does not have data in the data sheets
# Modal_type
# Sectors
# Selected Years
# Par_RegionalCCSLimit.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TagTechnologyToSector.csv
# Region
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TotalAnnualMaxCapacity.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_CapitalCost.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Something in the user input does not have data in the data sheets
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_TradeRoute.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# Something in the user input does not have data in the data sheets
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years
# Par_CapacityToActivityUnit.csv
# Region
# Something in the user input does not have data in the data sheets
# Technology
# Storage
# Fuel
# ModeOfOperation
# Emission
# Modal_type
# Sectors
# Selected Years

# %%
# Out:
# An error occurred: 'Region'

# %% [raw]
# # Initialize the Excel writer
# output_excel_file_path = os.path.join(output_excel_directory, 'output.xlsx')
# with pd.ExcelWriter(output_excel_file_path, engine='openpyxl') as writer:
#     unique_values_concatenated.to_excel(writer, sheet_name='Sets', index=False, header=True)
#     for filename in os.listdir(csv_directory):
#         if filename.endswith('.csv') and filename != excluded_file:
#             # Construct the full path to the CSV file
#             csv_file_path = os.path.join(csv_directory, filename)
#
#             df_first = pd.read_csv(csv_file_path, delimiter=';',header=None)
#             df_header = df_first.iloc[:4] #shweta
#             df_header = df_header.apply(lambda x: x.apply(lambda y: str(y).replace('.0', '')))
#             df_header = df_header.iloc[:4, :1]
#
#             # Read the CSV file into a Pandas DataFrame, skipping the first 4 rows
#             df = pd.read_csv(csv_file_path, delimiter=';', skiprows=4)
#
#             if "Region" in df.columns:
#                 # Filter the DataFrame based on whether the values in the "Region" column are present in unique_values
#                 filtered_df = df[df["Region"].isin(unique_values_region)]
#                 if "Region2" in df.columns:
#                     filtered_df = filtered_df[filtered_df["Region2"].isin(unique_values_region)]
#             else:
#                 # If "Region" column is not found, copy the entire DataFrame
#                 filtered_df = df.copy()
#
#             if "Technology" in df.columns:
#                 filtered_df = filtered_df[filtered_df["Technology"].isin(unique_values_technology)]
#             else:
#                 filtered_df = filtered_df.copy()
#
#             if "Year" in df.columns:
#                 filtered_df = filtered_df[filtered_df["Year"].isin(unique_values_year)]
#             else:
#                 filtered_df = filtered_df.copy()
#
#             filtered_df = pd.concat([filtered_df.columns.to_frame().T, filtered_df], ignore_index=True)
#             filtered_df.columns = range(len(df.columns))
#
#             df_final = pd.concat([df_header, filtered_df], axis=0)
#
#             df_final.replace('nan', '', inplace=True)
#             df_final.apply(lambda x: x.apply(lambda y: str(y).replace('.', ',')))
#
#             # Get the worksheet name without the .csv extension
#             worksheet_name = os.path.splitext(filename)[0]
#
#             # Store the DataFrame in the dictionary with the filename (without extension) as the key
#             data_frames[worksheet_name] = df_final
#
#             # Write the DataFrame to an Excel worksheet with the same filename (without extension)
#             df_final.to_excel(writer, sheet_name=worksheet_name, index=False, header=False)
#
#             # Construct the full path to the output CSV file
#             output_csv_file_path = os.path.join(output_csv_directory, filename)
#
#             # Save the filtered DataFrame to the CSV file without the index
#             df_final.to_csv(output_csv_file_path, index=False, header=False, decimal=',')

# %% [raw]
# # Initialize the Excel writer
# output_excel_file_path = os.path.join(output_excel_directory, 'output.xlsx')
# with pd.ExcelWriter(output_excel_file_path, engine='openpyxl') as writer:
#     for filename in os.listdir(csv_directory):
#
#         if filename.endswith('.csv'):
#             # Construct the full path to the CSV file
#             csv_file_path = os.path.join(csv_directory, filename)
#
#             # Get the worksheet name without the .csv extension
#             worksheet_name = os.path.splitext(filename)[0]
#
#             # Construct the full path to the output CSV file
#             output_csv_file_path = os.path.join(output_csv_directory, filename)
#
#             else:
#
#                 df_first = pd.read_csv(csv_file_path, delimiter=';',header=None)
#                 df_header = df_first.iloc[:4]
#                 df_header = df_header.apply(lambda x: x.apply(lambda y: str(y).replace('.0', '')))
#                 df_header = df_header.iloc[:4, :1]
#
#                 # Read the CSV file into a Pandas DataFrame, skipping the first 4 rows
#                 df = pd.read_csv(csv_file_path, delimiter=';', skiprows=4)
#
#                 if "Region" in df.columns:
#                     # Filter the DataFrame based on whether the values in the "Region" column are present in unique_values
#                     filtered_df = df[df["Region"].isin(unique_values)]
#                     if "Region2" in df.columns:
#                          filtered_df = filtered_df[filtered_df["Region2"].isin(unique_values)]
#                 else:
#                     # If "Region" column is not found, copy the entire DataFrame
#                     filtered_df = df.copy()
#
#                 filtered_df = filtered_df.columns.to_frame().T.append(filtered_df, ignore_index=True)
#                 filtered_df.columns = range(len(df.columns))
#
#                 df_final = pd.concat([df_header, filtered_df], axis=0)
#
#                 df_final.replace('nan', '', inplace=True)
#                 df_final.apply(lambda x: x.apply(lambda y: str(y).replace('.', ',')))
#
#                 # Store the DataFrame in the dictionary with the filename (without extension) as the key
#                 data_frames[worksheet_name] = df_final
#
#                 # Write the DataFrame to an Excel worksheet with the same filename (without extension)
#                 df_final.to_excel(writer, sheet_name=worksheet_name, index=False, header=False)
#
#
#                 # Save the filtered DataFrame to the CSV file without the index
#                 df_final.to_csv(output_csv_file_path, index=False, header=False, decimal=',')
