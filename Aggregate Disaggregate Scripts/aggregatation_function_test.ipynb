# %%
import os
import pandas as pd
import yaml

# %%
# Load the configuration from the YAML file
def load_config(config_file):
    with open(config_file, 'r') as file:
        config = yaml.safe_load(file)
    return config

# %%
def load_csvs(main_folder):
    for root, dirs, files in os.walk(main_folder):
        print(root)
        for file in files:
            if file.endswith('.csv'):
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                # Yield the DataFrame and the file path (optional, for reference)
                yield df, file_path

# %%
# Function to process unchanged files
def process_files(base_dir):
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith('csv'):
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                yield df, file_path

# %%
def process_unchanged_files(config, main_folder, output_path):
    # Process unchanged files
    unchanged_files = config['no_change_parameters'] #list of files
    # Load each CSV file from the main folder
    for df, file_path in process_files(main_folder):
        param_name = os.path.splitext(os.path.basename(file_path))[0]
        if param_name in unchanged_files:
            #print(f"Skipping {param_name} as it is in the no_change_parameters list.")
            file_path = os.path.join(output_path, f'{param_name}.csv')
            df.to_csv(file_path)

# %% [raw]
# def aggregate_data(df, method, index_count, regions_to_combine, new_regions):
#     group_by_columns = df.columns[:index_count].tolist()
#
#
#     if method == 'sum':
#
#         # Automatically detect numeric and non-numeric columns
#         aggregation_functions = {}
#         for col in df.columns:
#             if col in group_by_columns:
#                 continue
#
#             if pd.api.types.is_numeric_dtype(df[col]):
#                 aggregation_functions[col] = 'sum'
#             else:
#                 aggregation_functions[col] = 'first'  # Keep the first value for non-numeric columns
#
#         # Apply the aggregation dynamically
#         df = df.groupby(group_by_columns).agg(aggregation_functions).reset_index()
#         return df
#
#     elif method == 'average':
#         return df.groupby(group_by_columns).mean().reset_index()
#
#     elif method == 'copy':
#         return df.copy()
#
#     else:
#         raise ValueError(f"Aggregation method '{method}' is not supported.")

# %%
def aggregate_data(df, method, index_count, regions_to_combine, new_region, output_csv="aggregated_data.csv"):
    """
    Aggregates data in a DataFrame based on the given regions and saves the result as a new CSV file.

    Parameters:
        df (pd.DataFrame): The input DataFrame.
        method (str): Aggregation method (e.g., 'sum', 'mean').
        index_count (str): The column to use as the index for aggregation.
        regions_to_combine (list): List of region names to combine.
        new_region (str): Name for the new aggregated region.
        output_csv (str): Path to save the resulting CSV file.

    Returns:
        pd.DataFrame: The aggregated DataFrame.
    """
    if method not in ['sum', 'mean']:
        raise ValueError("Supported methods are 'sum' and 'mean'")

    # Filter rows corresponding to the regions to combine
    filtered_df = df[df[index_count].isin(regions_to_combine)]

    # Perform the aggregation
    if method == 'sum':
        aggregated_row = filtered_df.sum(numeric_only=True)
    elif method == 'mean':
        aggregated_row = filtered_df.mean(numeric_only=True)

    # Add the new region name to the index column
    aggregated_row[index_count] = new_region

    # Remove the original regions and append the aggregated row
    result_df = df[~df[index_count].isin(regions_to_combine)]
    result_df = pd.concat([result_df, pd.DataFrame([aggregated_row])], ignore_index=True)

    # Save the result to a new CSV file
    result_df.to_csv(output_csv, index=False)

    return result_df

# %%
def process_changed_files(config, main_folder, output_path):
    changed_files = config['changed_files'] # list of file with parameters
    
    #Load each CSV file from the main folder
    for df, file_path in process_files(main_folder):
        #combined_new_regions = pd.DataFrame()
        param_name = os.path.splitext(os.path.basename(file_path))[0]
        # Construct the full file path
        file_path = os.path.join(output_path, f'{param_name}.csv')
        for file in changed_files:
            if param_name == file['file_name']:
                method = file['method']
                index_count = file['index_count']
                regions_to_combine = file['regions_to_combine']
                new_regions = file['new_regions']
                print(param_name, method, index_count, new_regions, regions_to_combine)
                df.set_index(df.columns[:index_count].tolist(), inplace=True)
                
                # Apply aggregation based on config
                aggregated_df = aggregate_data(df, method, index_count, regions_to_combine, new_regions) 
                
                print(aggregated_df.head())

# %%
pd.set_option('display.max_rows', None)
base_dir = "/Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters"
output_dir = "/Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/DataNew"
config = load_config("config.yaml")
process_unchanged_files(config, base_dir, output_dir)
process_changed_files(config, base_dir, output_dir)
# Out:
# Par_RegionalModelPeriodEmissionLimit sum 2 ['SCANDINAVIA'] ['NO', 'SE']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/havnett/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/envs/havnett/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/havnett/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/ww/34wy9_qd5f5_r6d15cv5m8rh0000gn/T/ipykernel_86833/3465306363.py in <module>
#       4 config = load_config("config.yaml")
#       5 process_unchanged_files(config, base_dir, output_dir)
# ----> 6 process_changed_files(config, base_dir, output_dir)
#
# /var/folders/ww/34wy9_qd5f5_r6d15cv5m8rh0000gn/T/ipykernel_86833/1273108868.py in process_changed_files(config, main_folder, output_path)
#      18
#      19                 # Apply aggregation based on config
# ---> 20                 aggregated_df = aggregate_data(df, method, index_count, regions_to_combine, new_regions)
#      21
#      22                 print(aggregated_df.head())
#
# /var/folders/ww/34wy9_qd5f5_r6d15cv5m8rh0000gn/T/ipykernel_86833/4196780134.py in aggregate_data(df, method, index_count, regions_to_combine, new_region, output_csv)
#      18
#      19     # Filter rows corresponding to the regions to combine
# ---> 20     filtered_df = df[df[index_count].isin(regions_to_combine)]
#      21
#      22     # Perform the aggregation
#
# ~/opt/anaconda3/envs/havnett/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/havnett/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 2

# %% [raw]
# def process_files(config, main_folder, output_path):
#     changed_files = config['parameters']['changed_files']
#
#     for df, file_path in load_csvs(main_folder):
#         print(df.columns)
#         param_name = os.path.splitext(os.path.basename(file_path))[0]
#         print('Extracted param_name:', param_name)
#
#         if param_name in no_change_files:
#             print(f"Skipping {param_name} as it is in the no_change_parameters list.")
#             continue
#
#         # Apply the changes based on the config
#         param_config = config.get(param_name, None)
#
#         if not param_config:
#             print(f"No configuration found for {param_name}.")
#             continue
#
#         agg_method = param_config.get('aggregation_Method')
#         index_count = param_config.get('index_count')
#
#         # Fetch region-specific configuration for this parameter from regions.yaml
#         region_config = config.get('regions', None)
#         new_region = config.get('new_regions')
#         print(new_region)
#
#         if region_config:
#             # Get regions to aggregate and new region
#             regions_to_aggregate = region_config
#
#
#             # Check if regions are defined properly
#             if not regions_to_aggregate or not new_region:
#                 print(f"Invalid region configuration for {param_name}. Skipping.")
#                 continue
#         else:
#             print(f"No region configuration found for {param_name}. Skipping.")
#             continue
#
#         # Filter the data to include only rows with regions to aggregate
#         if 'Region' in df.columns:
#             df_to_aggregate = df[df['Region'].isin(regions_to_aggregate)]
#         else:
#             print(f"No 'Region' column found in {param_name}. Skipping.")
#             continue
#
#         # Apply aggregation based on config
#         aggregated_df = aggregate_data(df_to_aggregate, agg_method, index_count) # not creating new region. need to take a look in aggregate_data function
#         print(aggregated_df.tail())
#         aggregated_df.to_csv('agg_test.csv')
#
#         #require fixing
#         aggregated_df['Region'] = new_region
#         df = pd.concat([df, aggregated_df], ignore_index=True)
#
#         # Save the updated DataFrame to a new location
#         df.to_csv(output_path, index=False)
#         print(f"Updated {param_name} with aggregated data for new region {output_path}.")

# %%
config = load_config('config.yaml')

#regions_config = load_config('regions.yaml')

main_folder = '/Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters' 
output_path = '/Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/DataNew/Parameters' 

process_files(config, main_folder, output_path)
# Out:
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMaxActivity
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TotalAnnualMaxActivity
# None
# No region configuration found for Par_TotalAnnualMaxActivity. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMaxActivity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_REMinProductionTarget
# Index(['Region', 'Fuel', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_REMinProductionTarget
# None
# No region configuration found for Par_REMinProductionTarget. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_REMinProductionTarget/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TechnologyFromStorage
# Index(['Technology', 'Storage', 'Mode_of_operation', 'Year', 'Value',
#        'Unnamed: 5', 'Unit', 'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TechnologyFromStorage
# Skipping Par_TechnologyFromStorage as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TechnologyFromStorage/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ReserveMargin
# Index(['Region', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ReserveMargin
# None
# No region configuration found for Par_ReserveMargin. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ReserveMargin/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_FixedCost
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_FixedCost
# Skipping Par_FixedCost as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_FixedCost/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/00_Sets&Tags
# Index(['Fuel', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RETagFuel
# No configuration found for Par_RETagFuel.
# Index(['Region', 'Fuel', 'Year', 'Value'], dtype='object')
# Extracted param_name: Par_ReserveMarginTagFuel
# No configuration found for Par_ReserveMarginTagFuel.
# Index(['Technology', 'Value'], dtype='object')
# Extracted param_name: Par_TagElectricTechnology
# No configuration found for Par_TagElectricTechnology.
# Index(['StorageLimitOffset'], dtype='object')
# Extracted param_name: Settings_StorageLimitOffset
# No configuration found for Settings_StorageLimitOffset.
# Index(['NewRESCapacity'], dtype='object')
# Extracted param_name: Settings_NewRESCapacity
# No configuration found for Settings_NewRESCapacity.
# Index(['Region'], dtype='object')
# Extracted param_name: Sets_Region
# No configuration found for Sets_Region.
# Index(['Technology', 'Mode_of_operation', 'ModalType', 'Value'], dtype='object')
# Extracted param_name: Par_TagTechnologyToModalType
# No configuration found for Par_TagTechnologyToModalType.
# Index(['Technology'], dtype='object')
# Extracted param_name: Sets_Technology
# No configuration found for Sets_Technology.
# Index(['Technology', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RETagTechnology
# No configuration found for Par_RETagTechnology.
# Index(['Sectors'], dtype='object')
# Extracted param_name: Sets_Sectors
# No configuration found for Sets_Sectors.
# Index(['Region', 'Technology', 'Year', 'Value'], dtype='object')
# Extracted param_name: Par_ReserveMarginTagTechnology
# No configuration found for Par_ReserveMarginTagTechnology.
# Index(['Technology', 'Subset', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TagTechnologyToSubsets
# No configuration found for Par_TagTechnologyToSubsets.
# Index(['Region', 'Technology', 'Emission', 'Year', 'Value'], dtype='object')
# Extracted param_name: Par_EmissionPenaltyTagTech
# No configuration found for Par_EmissionPenaltyTagTech.
# Index(['Mode_of_operation'], dtype='object')
# Extracted param_name: Sets_Mode_of_operation
# No configuration found for Sets_Mode_of_operation.
# Index(['Emission'], dtype='object')
# Extracted param_name: Sets_Emission
# No configuration found for Sets_Emission.
# Index(['Fuel', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TagTimeIndependentFuel
# No configuration found for Par_TagTimeIndependentFuel.
# Index(['Fuel', 'Subset', 'Value', 'Unnamed: 3', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TagFuelToSubsets
# No configuration found for Par_TagFuelToSubsets.
# Index(['Fuel', 'Sector', 'Value'], dtype='object')
# Extracted param_name: Par_TagDemandFuelToSector
# No configuration found for Par_TagDemandFuelToSector.
# Index(['ModalType'], dtype='object')
# Extracted param_name: Sets_ModalType
# No configuration found for Sets_ModalType.
# Index(['InvestmentLimit'], dtype='object')
# Extracted param_name: Settings_InvestmentLimit
# No configuration found for Settings_InvestmentLimit.
# Index(['Storage'], dtype='object')
# Extracted param_name: Sets_Storage
# No configuration found for Sets_Storage.
# Index(['Technology', 'Sector', 'Value'], dtype='object')
# Extracted param_name: Par_TagTechnologyToSector
# No configuration found for Par_TagTechnologyToSector.
# Index(['Fuel'], dtype='object')
# Extracted param_name: Sets_Fuel
# No configuration found for Sets_Fuel.
# Index(['Technology', 'Value'], dtype='object')
# Extracted param_name: Par_CapacityToActivityUnit
# No configuration found for Par_CapacityToActivityUnit.
# Index(['Year'], dtype='object')
# Extracted param_name: Sets_Year
# No configuration found for Sets_Year.
# Index(['DepreciationMethod'], dtype='object')
# Extracted param_name: Settings_DepreciationMethod
# No configuration found for Settings_DepreciationMethod.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalCCSLimit
# Index(['Region', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RegionalCCSLimit
# None
# No region configuration found for Par_RegionalCCSLimit. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalCCSLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModalSplitByFuel
# Index(['Region', 'Fuel', 'Year', 'ModalType', 'Value', 'Unnamed: 5', 'Unit',
#        'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ModalSplitByFuel
# None
# No region configuration found for Par_ModalSplitByFuel. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModalSplitByFuel/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CapitalCost
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_CapitalCost
# None
# No region configuration found for Par_CapitalCost. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CapitalCost/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_EmissionsPenalty
# Index(['Region', 'Emission', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_EmissionsPenalty
# No configuration found for Par_EmissionsPenalty.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_EmissionsPenalty/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_EmissionContentPerFuel
# Index(['Fuel', 'Emission', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_EmissionContentPerFuel
# Skipping Par_EmissionContentPerFuel as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_EmissionContentPerFuel/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AnnualEmissionLimit
# Index(['Emission', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_AnnualEmissionLimit
# Skipping Par_AnnualEmissionLimit as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AnnualEmissionLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TechnologyDiscountRate
# Index(['Region', 'Technology', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TechnologyDiscountRate
# None
# No region configuration found for Par_TechnologyDiscountRate. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TechnologyDiscountRate/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModelPeriodActivityMaxLimit
# Index(['Region', 'Technology', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ModelPeriodActivityMaxLimit
# No configuration found for Par_ModelPeriodActivityMaxLimit.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModelPeriodActivityMaxLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ResidualCapacity
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ResidualCapacity
# None
# No region configuration found for Par_ResidualCapacity. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ResidualCapacity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_InputActivityRatio
# Index(['Region', 'Technology', 'Fuel', 'Mode_of_operation', 'Year', 'Value',
#        'Unnamed: 6', 'Unit', 'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_InputActivityRatio
# Skipping Par_InputActivityRatio as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_InputActivityRatio/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMinCapacity
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TotalAnnualMinCapacity
# Skipping Par_TotalAnnualMinCapacity as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMinCapacity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AvailabilityFactor
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_AvailabilityFactor
# No configuration found for Par_AvailabilityFactor.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AvailabilityFactor/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_OperationalLife
# Index(['Technology', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_OperationalLife
# Skipping Par_OperationalLife as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_OperationalLife/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_EmissionActivityRatio
# Index(['Region', 'Technology', 'Mode_of_operation', 'Emission', 'Year',
#        'Value', 'Unnamed: 6', 'Unit', 'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_EmissionActivityRatio
# Skipping Par_EmissionActivityRatio as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_EmissionActivityRatio/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_GrowthRateTradeCapacity
# Index(['Region', 'Region2', 'Fuel', 'Year', 'Value', 'Unnamed: 5', 'Unit',
#        'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_GrowthRateTradeCapacity
# None
# No region configuration found for Par_GrowthRateTradeCapacity. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_GrowthRateTradeCapacity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_VariableCost
# Index(['Region', 'Technology', 'Mode_of_operation', 'Year', 'Value',
#        'Unnamed: 5', 'Unit', 'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_VariableCost
# No configuration found for Par_VariableCost.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_VariableCost/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModelPeriodEmissionLimit
# Index(['Emission', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ModelPeriodEmissionLimit
# Skipping Par_ModelPeriodEmissionLimit as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModelPeriodEmissionLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ProductionGrowthLimit
# Index(['Fuel', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ProductionGrowthLimit
# Skipping Par_ProductionGrowthLimit as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ProductionGrowthLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeCapacity
# Index(['Region', 'Region.1', 'Fuel', 'Year', 'Value', 'Unnamed: 5', 'Unit',
#        'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TradeCapacity
# None
# No region configuration found for Par_TradeCapacity. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeCapacity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_OperationalLifeStorage
# Index(['Storage', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_OperationalLifeStorage
# Skipping Par_OperationalLifeStorage as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_OperationalLifeStorage/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalAnnualEmissionLimit
# Index(['Region', 'Emission', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RegionalAnnualEmissionLimit
# None
# No region configuration found for Par_RegionalAnnualEmissionLimit. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalAnnualEmissionLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CommissionedTradeCapacity
# Index(['Region', 'Region2', 'Fuel', 'Year', 'Value', 'Unnamed: 5', 'Unit',
#        'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_CommissionedTradeCapacity
# No configuration found for Par_CommissionedTradeCapacity.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CommissionedTradeCapacity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AnnualExogenousEmission
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_AnnualExogenousEmission
# None
# No region configuration found for Par_AnnualExogenousEmission. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AnnualExogenousEmission/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ResidualStorageCapacity
# Index(['Region', 'Storage', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ResidualStorageCapacity
# Skipping Par_ResidualStorageCapacity as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ResidualStorageCapacity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RampingDownFactor
# Index(['Technology', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RampingDownFactor
# Skipping Par_RampingDownFactor as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RampingDownFactor/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_StorageLevelStart
# Index(['Region', 'Storage', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_StorageLevelStart
# Skipping Par_StorageLevelStart as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_StorageLevelStart/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalModelPeriodEmissionLimit
# Index(['Region', 'Emission', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RegionalModelPeriodEmissionLimit
# None
# No region configuration found for Par_RegionalModelPeriodEmissionLimit. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalModelPeriodEmissionLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TechnologyToStorage
# Index(['Technology', 'Storage', 'Mode_of_operation', 'Year', 'Value',
#        'Unnamed: 5', 'Unit', 'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TechnologyToStorage
# Skipping Par_TechnologyToStorage as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TechnologyToStorage/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_GeneralDiscountRate
# Index(['Region', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_GeneralDiscountRate
# None
# No region configuration found for Par_GeneralDiscountRate. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_GeneralDiscountRate/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_BaseYearProduction
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_BaseYearProduction
# None
# No region configuration found for Par_BaseYearProduction. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_BaseYearProduction/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeCapacityGrowthCosts
# Index(['Region', 'Region.1', 'Fuel', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TradeCapacityGrowthCosts
# None
# No region configuration found for Par_TradeCapacityGrowthCosts. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeCapacityGrowthCosts/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_MinStorageCharge
# Index(['Region', 'Storage', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_MinStorageCharge
# Skipping Par_MinStorageCharge as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_MinStorageCharge/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ProductionChangeCost
# Index(['Technology', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ProductionChangeCost
# Skipping Par_ProductionChangeCost as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ProductionChangeCost/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModelPeriodExogenousEmission
# Index(['Region', 'Emission', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_ModelPeriodExogenousEmission
# Skipping Par_ModelPeriodExogenousEmission as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_ModelPeriodExogenousEmission/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeRoute
# Index(['Region', 'Region.1', 'Fuel', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TradeRoute
# None
# No region configuration found for Par_TradeRoute. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeRoute/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_SocialDiscountRate
# Index(['Region', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_SocialDiscountRate
# None
# No region configuration found for Par_SocialDiscountRate. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_SocialDiscountRate/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_SpecifiedAnnualDemand
# Index(['Region', 'Fuel', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_SpecifiedAnnualDemand
# None
# No region configuration found for Par_SpecifiedAnnualDemand. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_SpecifiedAnnualDemand/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMaxCapacity
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TotalAnnualMaxCapacity
# None
# No region configuration found for Par_TotalAnnualMaxCapacity. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMaxCapacity/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalBaseYearProduction
# Index(['Region', 'Technology', 'Fuel', 'Year', 'Value', 'Unnamed: 5', 'Unit',
#        'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RegionalBaseYearProduction
# None
# No region configuration found for Par_RegionalBaseYearProduction. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RegionalBaseYearProduction/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_SelfSufficiency
# Index(['Region', 'Fuel', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_SelfSufficiency
# Skipping Par_SelfSufficiency as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_SelfSufficiency/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_OutputActivityRatio
# Index(['Region', 'Technology', 'Fuel', 'Mode_of_operation', 'Year', 'Value',
#        'Unnamed: 6', 'Unit', 'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_OutputActivityRatio
# None
# No region configuration found for Par_OutputActivityRatio. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_OutputActivityRatio/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_BaseYearSlack
# Index(['Fuel', 'Value', 'Unnamed: 2', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_BaseYearSlack
# Skipping Par_BaseYearSlack as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_BaseYearSlack/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CapitalCostStorage
# Index(['Region', 'Storage', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_CapitalCostStorage
# Skipping Par_CapitalCostStorage as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CapitalCostStorage/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeLossFactor
# Index(['Fuel', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source', 'Updated at',
#        'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TradeLossFactor
# Skipping Par_TradeLossFactor as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeLossFactor/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeCosts
# Index(['Fuel', 'Region', 'Region2', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TradeCosts
# None
# No region configuration found for Par_TradeCosts. Skipping.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TradeCosts/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RampingUpFactor
# Index(['Technology', 'Year', 'Value', 'Unnamed: 3', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_RampingUpFactor
# Skipping Par_RampingUpFactor as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_RampingUpFactor/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AnnualSectoralEmissionLimit
# Index(['Emission', 'Sector', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_AnnualSectoralEmissionLimit
# Skipping Par_AnnualSectoralEmissionLimit as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_AnnualSectoralEmissionLimit/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CapacityFactor
# Index(['Region', 'Technology', 'Timeslice', 'Year', 'Value', 'Unnamed: 5',
#        'Unit', 'Source', 'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_CapacityFactor
# Skipping Par_CapacityFactor as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_CapacityFactor/Europe_openENTRANCE_technoFriendly
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMinActivity
# Index(['Region', 'Technology', 'Year', 'Value', 'Unnamed: 4', 'Unit', 'Source',
#        'Updated at', 'Updated by'],
#       dtype='object')
# Extracted param_name: Par_TotalAnnualMinActivity
# Skipping Par_TotalAnnualMinActivity as it is in the no_change_parameters list.
# /Users/shwetat/Projects/Genesys-mod_data_repo/GENeSYS_MOD.data/Data/Parameters/Par_TotalAnnualMinActivity/Europe_openENTRANCE_technoFriendly
